# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahma-up/ADD-ON/blob/main/Day_1_Scientific_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.DataFrame({
    'Name' : ['Asha','Ravi','Neha','Kiran'],
    'Age': [22,25,28,30],
    'Marks':[80,85,90,88]
},index=[1,2,3,4])

# %%
df
# Out:
#     Name  Age  Marks
# 1   Asha   22     80
# 2   Ravi   25     85
# 3   Neha   28     90
# 4  Kiran   30     88

# %%
data ={
    'Name':['Alice','Bob','Charlie'],
    'Age':[25,30,35],
    'Salary':[50000,60000,70000],
    'Department':['IT','HR','IT']
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Salary Department
# 0    Alice   25   50000         IT
# 1      Bob   30   60000         HR
# 2  Charlie   35   70000         IT

# %%
df = pd.read_csv("/content/sales_data_sample.csv",encoding='latin1')

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.tail()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2818  12/2/2004 0:00   Shipped       4        12     2004  ...
# 2819  1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820   3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821  3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                ADDRESSLINE1  ADDRESSLINE2      CITY STATE POSTALCODE  COUNTRY  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df.shape
# Out:
# (2823, 25)

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
import pandas as pd
df = pd.read_csv("/content/sales_data_sample.csv",encoding='latin1')
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
df.isnull()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  SALES  \
# 0           False            False      False            False  False
# 1           False            False      False            False  False
# 2           False            False      False            False  False
# 3           False            False      False            False  False
# 4           False            False      False            False  False
# ...           ...              ...        ...              ...    ...
# 2818        False            False      False            False  False
# 2819        False            False      False            False  False
# 2820        False            False      False            False  False
# 2821        False            False      False            False  False
# 2822        False            False      False            False  False
#
#       ORDERDATE  STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  ADDRESSLINE1  \
# ...

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2818    False
# 2819    False
# 2820    False
# 2821    False
# 2822    False
# Length: 2823, dtype: bool

# %%
df['COUNTRY']
# Out:
# 0           USA
# 1        France
# 2        France
# 3           USA
# 4           USA
#          ...
# 2818      Spain
# 2819    Finland
# 2820      Spain
# 2821     France
# 2822        USA
# Name: COUNTRY, Length: 2823, dtype: object

# %%
df[['POSTALCODE','COUNTRY']]
# Out:
#      POSTALCODE  COUNTRY
# 0         10022      USA
# 1         51100   France
# 2         75508   France
# 3         90003      USA
# 4           NaN      USA
# ...         ...      ...
# 2818      28034    Spain
# 2819      90110  Finland
# 2820      28034    Spain
# 2821      31000   France
# 2822      51003      USA
#
# [2823 rows x 2 columns]

# %%
df[['TERRITORY','COUNTRY','ORDERNUMBER']]
# Out:
#      TERRITORY  COUNTRY  ORDERNUMBER
# 0          NaN      USA        10107
# 1         EMEA   France        10121
# 2         EMEA   France        10134
# 3          NaN      USA        10145
# 4          NaN      USA        10159
# ...        ...      ...          ...
# 2818      EMEA    Spain        10350
# 2819      EMEA  Finland        10373
# 2820      EMEA    Spain        10386
# 2821      EMEA   France        10397
# 2822       NaN      USA        10414
#
# [2823 rows x 3 columns]

# %%
df[['STATE','COUNTRY']]
# Out:
#      STATE  COUNTRY
# 0       NY      USA
# 1      NaN   France
# 2      NaN   France
# 3       CA      USA
# 4       CA      USA
# ...    ...      ...
# 2818   NaN    Spain
# 2819   NaN  Finland
# 2820   NaN    Spain
# 2821   NaN   France
# 2822    MA      USA
#
# [2823 rows x 2 columns]

# %%
df['CITY']
# Out:
# 0                 NYC
# 1               Reims
# 2               Paris
# 3            Pasadena
# 4       San Francisco
#             ...
# 2818           Madrid
# 2819             Oulu
# 2820           Madrid
# 2821         Toulouse
# 2822           Boston
# Name: CITY, Length: 2823, dtype: object

# %% [markdown]
# Duplicates
# name     mark   age   gender
# A        10      21    M
# A        20      21    M
# B        15      22    F
# A        10      21    M
# C        30      23     F

# %%
df[20:]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 20          10341               41     100.00                9  7737.93
# 21          10361               20      72.55               13  1451.00
# 22          10375               21      34.91               12   733.11
# 23          10388               42      76.36                4  3207.12
# 24          10403               24     100.00                7  2434.56
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df['COUNTRY'].value_counts()
# Out:
# COUNTRY
# USA            1004
# Spain           342
# France          314
# Australia       185
# UK              144
# Italy           113
# Finland          92
# Norway           85
# Singapore        79
# Canada           70
# Denmark          63
# Germany          62
# Sweden           57
# Austria          55
# Japan            52
# Belgium          33
# Switzerland      31
# Philippines      26
# Ireland          16
# Name: count, dtype: int64

# %%
df['COUNTRY'].unique()
# Out:
# array(['USA', 'France', 'Norway', 'Australia', 'Finland', 'Austria', 'UK',
#        'Spain', 'Sweden', 'Singapore', 'Canada', 'Japan', 'Italy',
#        'Denmark', 'Belgium', 'Philippines', 'Germany', 'Switzerland',
#        'Ireland'], dtype=object)

# %%
df['COUNTRY'].nunique()
# Out:
# 19

# %%
df['CITY'].value_counts()
# Out:
# CITY
# Madrid         304
# San Rafael     180
# NYC            152
# Singapore       79
# Paris           70
#               ...
# Graz            15
# Munich          14
# Los Angeles     14
# Burbank         13
# Charleroi        8
# Name: count, Length: 73, dtype: int64

# %%
df['CITY'].unique()
# Out:
# array(['NYC', 'Reims', 'Paris', 'Pasadena', 'San Francisco', 'Burlingame',
#        'Lille', 'Bergen', 'Melbourne', 'Newark', 'Bridgewater', 'Nantes',
#        'Cambridge', 'Helsinki', 'Stavern', 'Allentown', 'Salzburg',
#        'Chatswood', 'New Bedford', 'Liverpool', 'Madrid', 'Lule',
#        'Singapore', 'South Brisbane', 'Philadelphia', 'Lyon', 'Vancouver',
#        'Burbank', 'New Haven', 'Minato-ku', 'Torino', 'Boras',
#        'Versailles', 'San Rafael', 'Nashua', 'Brickhaven', 'North Sydney',
#        'Montreal', 'Osaka', 'White Plains', 'Kobenhavn', 'London',
#        'Toulouse', 'Barcelona', 'Los Angeles', 'San Diego', 'Bruxelles',
#        'Tsawassen', 'Boston', 'Cowes', 'Oulu', 'San Jose', 'Graz',
#        'Makati City', 'Marseille', 'Koln', 'Gensve', 'Reggio Emilia',
#        'Frankfurt', 'Espoo', 'Dublin', 'Manchester', 'Aaarhus',
#        'Glendale', 'Sevilla', 'Brisbane', 'Strasbourg', 'Las Vegas',
#        'Oslo', 'Bergamo', 'Glen Waverly', 'Munich', 'Charleroi'],
# ...

# %%
df['CITY'].nunique()
# Out:
# 73

# %%
df.loc[0]
# Out:
# ORDERNUMBER                           10107
# QUANTITYORDERED                          30
# PRICEEACH                              95.7
# ORDERLINENUMBER                           2
# SALES                                2871.0
# ORDERDATE                    2/24/2003 0:00
# STATUS                              Shipped
# QTR_ID                                    1
# MONTH_ID                                  2
# YEAR_ID                                2003
# PRODUCTLINE                     Motorcycles
# MSRP                                     95
# PRODUCTCODE                        S10_1678
# CUSTOMERNAME              Land of Toys Inc.
# PHONE                            2125557818
# ADDRESSLINE1        897 Long Airport Avenue
# ADDRESSLINE2                            NaN
# CITY                                    NYC
# STATE                                    NY
# POSTALCODE                            10022
# COUNTRY                                 USA
# ...

# %%
df.loc[25,'ORDERDATE']
# Out:
# '5/13/2005 0:00'

# %%
df.loc[25,['COUNTRY','STATE','TERRITORY']]
# Out:
# COUNTRY      Spain
# STATE          NaN
# TERRITORY     EMEA
# Name: 25, dtype: object

# %%
df.loc[0:25]
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0         10107               30      95.70                2  2871.00
# 1         10121               34      81.35                5  2765.90
# 2         10134               41      94.74                2  3884.34
# 3         10145               45      83.26                6  3746.70
# 4         10159               49     100.00               14  5205.27
# 5         10168               36      96.66                1  3479.76
# 6         10180               29      86.13                9  2497.77
# 7         10188               48     100.00                1  5512.32
# 8         10201               22      98.57                2  2168.54
# 9         10211               41     100.00               14  4708.44
# 10        10223               37     100.00                1  3965.66
# 11        10237               23     100.00                7  2333.12
# ...

# %%
df.iloc[0:50,2]
# Out:
# 0      95.70
# 1      81.35
# 2      94.74
# 3      83.26
# 4     100.00
# 5      96.66
# 6      86.13
# 7     100.00
# 8      98.57
# 9     100.00
# 10    100.00
# 11    100.00
# 12    100.00
# 13    100.00
# 14     92.83
# 15    100.00
# 16    100.00
# 17    100.00
# 18     94.74
# 19    100.00
# 20    100.00
# 21     72.55
# 22     34.91
# 23     76.36
# 24    100.00
# 25    100.00
# 26    100.00
# 27    100.00
# 28    100.00
# 29    100.00
# 30    100.00
# 31    100.00
# 32    100.00
# 33    100.00
# 34    100.00
# 35    100.00
# 36    100.00
# 37    100.00
# 38    100.00
# 39    100.00
# 40    100.00
# 41    100.00
# 42    100.00
# 43    100.00
# 44    100.00
# 45    100.00
# 46    100.00
# 47    100.00
# 48    100.00
# 49    100.00
# Name: PRICEEACH, dtype: float64

# %%
df.iloc[10:23,5]
# Out:
# 10     2/20/2004 0:00
# 11      4/5/2004 0:00
# 12     5/18/2004 0:00
# 13     6/28/2004 0:00
# 14     7/23/2004 0:00
# 15     8/27/2004 0:00
# 16     9/30/2004 0:00
# 17    10/15/2004 0:00
# 18     11/2/2004 0:00
# 19    11/15/2004 0:00
# 20    11/24/2004 0:00
# 21    12/17/2004 0:00
# 22      2/3/2005 0:00
# Name: ORDERDATE, dtype: object

# %%
df.iloc[0:30,[0,3,2]]
# Out:
#     ORDERNUMBER  ORDERLINENUMBER  PRICEEACH
# 0         10107                2      95.70
# 1         10121                5      81.35
# 2         10134                2      94.74
# 3         10145                6      83.26
# 4         10159               14     100.00
# 5         10168                1      96.66
# 6         10180                9      86.13
# 7         10188                1     100.00
# 8         10201                2      98.57
# 9         10211               14     100.00
# 10        10223                1     100.00
# 11        10237                7     100.00
# 12        10251                2     100.00
# 13        10263                2     100.00
# 14        10275                1      92.83
# 15        10285                6     100.00
# 16        10299                9     100.00
# 17        10309                5     100.00
# 18        10318                1      94.74
# 19        10329                1     100.00
# ...

# %%
df.iloc[0:23,[14,17,20]]
# Out:
#                PHONE           CITY    COUNTRY
# 0         2125557818            NYC        USA
# 1         26.47.1555          Reims     France
# 2   +33 1 46 62 7555          Paris     France
# 3         6265557265       Pasadena        USA
# 4         6505551386  San Francisco        USA
# 5         6505556809     Burlingame        USA
# 6         20.16.1555          Lille     France
# 7      +47 2267 3215         Bergen     Norway
# 8         6505555787  San Francisco        USA
# 9     (1) 47.55.6555          Paris     France
# 10      03 9520 4555      Melbourne  Australia
# 11        2125551500            NYC        USA
# 12        2015559350         Newark        USA
# 13        2035552570    Bridgewater        USA
# 14        40.67.8555         Nantes     France
# 15        6175558555      Cambridge        USA
# 16       90-224 8555       Helsinki    Finland
# 17        07-98 9555        Stavern     Norway
# 18        2155551555      Allentown        USA
# ...

# %% [markdown]
# iloc- for index value
# [0:30]- from 0th  to 29th row
# [0:30],[0,3,2]- 0,3,2 is the columns that we need
# TO DISPLAY A COLUMN USE df['column name']

# %%
df.drop_duplicates(inplace=True)

# %%
df.rename(columns={'STATE':'STATE_NAME'},inplace=True)

# %%
df.rename(columns={'CITY':'REGION'},inplace=True)

# %%
df['CITY']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CITY'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2130/1322997864.py in <cell line: 0>()
# ----> 1 df['CITY']
#
# ...

# %%
df['ORDERDATE']
# Out:
# 0        2/24/2003 0:00
# 1         5/7/2003 0:00
# 2         7/1/2003 0:00
# 3        8/25/2003 0:00
# 4       10/10/2003 0:00
#              ...
# 2818     12/2/2004 0:00
# 2819     1/31/2005 0:00
# 2820      3/1/2005 0:00
# 2821     3/28/2005 0:00
# 2822      5/6/2005 0:00
# Name: ORDERDATE, Length: 2823, dtype: object

# %%
df['ORDERDATE']=pd.to_datetime(df['ORDERDATE'])

# %%
df['ORDERDATE']
# Out:
# 0      2003-02-24
# 1      2003-05-07
# 2      2003-07-01
# 3      2003-08-25
# 4      2003-10-10
#           ...
# 2818   2004-12-02
# 2819   2005-01-31
# 2820   2005-03-01
# 2821   2005-03-28
# 2822   2005-05-06
# Name: ORDERDATE, Length: 2823, dtype: datetime64[ns]

# %%
df['year']=df['ORDERDATE'].dt.year

# %%
df['year']
# Out:
# 0       2003
# 1       2003
# 2       2003
# 3       2003
# 4       2003
#         ...
# 2818    2004
# 2819    2005
# 2820    2005
# 2821    2005
# 2822    2005
# Name: year, Length: 2823, dtype: int32

# %%
df['month']=df['ORDERDATE'].dt.month

# %%
df['month']
# Out:
# 0        2
# 1        5
# 2        7
# 3        8
# 4       10
#         ..
# 2818    12
# 2819     1
# 2820     3
# 2821     3
# 2822     5
# Name: month, Length: 2823, dtype: int32

# %%
df['date']=df['ORDERDATE'].dt.date

# %%
df['date']
# Out:
# 0       2003-02-24
# 1       2003-05-07
# 2       2003-07-01
# 3       2003-08-25
# 4       2003-10-10
#            ...
# 2818    2004-12-02
# 2819    2005-01-31
# 2820    2005-03-01
# 2821    2005-03-28
# 2822    2005-05-06
# Name: date, Length: 2823, dtype: object

# %%
df['PROFIT_EST']=df['SALES']*0.2

# %%
df['PROFIT_EST']
# Out:
# 0        574.200
# 1        553.180
# 2        776.868
# 3        749.340
# 4       1041.054
#           ...
# 2818     448.880
# 2819     795.702
# 2820    1083.514
# 2821     423.232
# 2822     615.888
# Name: PROFIT_EST, Length: 2823, dtype: float64

# %%
df.drop('PROFIT_EST',axis=1,inplace=True)

# %%
df['FULLNAME']=df['CONTACTFIRSTNAME']+' ' +df['CONTACTLASTNAME']

# %%
df['FULLNAME']
# Out:
# 0                Kwai Yu
# 1           Paul Henriot
# 2        Daniel Da Cunha
# 3            Julie Young
# 4            Julie Brown
#               ...
# 2818        Diego Freyre
# 2819    Pirkko Koskitalo
# 2820        Diego Freyre
# 2821      Annette Roulet
# 2822        Juri Yoshido
# Name: FULLNAME, Length: 2823, dtype: object

# %%
monthly_sales=df.groupby('MONTH_ID')['SALES'].sum()

# %%
monthly_sales
monthly_sales.plot(kind='pie')
# Out:
# <Axes: ylabel='SALES'>

# %%
df.groupby('COUNTRY')['SALES'].sum()
# Out:
# COUNTRY
# Australia       630623.10
# Austria         202062.53
# Belgium         108412.62
# Canada          224078.56
# Denmark         245637.15
# Finland         329581.91
# France         1110916.52
# Germany         220472.09
# Ireland          57756.43
# Italy           374674.31
# Japan           188167.81
# Norway          307463.70
# Philippines      94015.73
# Singapore       288488.41
# Spain          1215686.92
# Sweden          210014.21
# Switzerland     117713.56
# UK              478880.46
# USA            3627982.83
# Name: SALES, dtype: float64

# %%
orders_per_year=df.groupby('YEAR_ID')['ORDERNUMBER'].nunique()
print(orders_per_year)
# Out:
# YEAR_ID
# 2003    104
# 2004    144
# 2005     59
# Name: ORDERNUMBER, dtype: int64

# %%
avg_sales_product=df.groupby('PRODUCTCODE')['SALES'].mean()
print(avg_sales_product)
# Out:
# PRODUCTCODE
# S10_1678     3734.884615
# S10_1949     6824.036786
# S10_2016     4077.594615
# S10_4698     6553.887308
# S10_4757     4188.656667
#                 ...
# S700_3505    3406.361923
# S700_3962    3095.489231
# S700_4002    2821.319630
# S72_1253     1913.400741
# S72_3212     2348.619231
# Name: SALES, Length: 109, dtype: float64

# %%
df['DEALSIZE']
# Out:
# 0        Small
# 1        Small
# 2       Medium
# 3       Medium
# 4       Medium
#          ...
# 2818     Small
# 2819    Medium
# 2820    Medium
# 2821     Small
# 2822    Medium
# Name: DEALSIZE, Length: 2823, dtype: object

# %%
df['DEALSIZE']=df['DEALSIZE'].str.upper()

# %%
df['DEALSIZE']
# Out:
# 0        SMALL
# 1        SMALL
# 2       MEDIUM
# 3       MEDIUM
# 4       MEDIUM
#          ...
# 2818     SMALL
# 2819    MEDIUM
# 2820    MEDIUM
# 2821     SMALL
# 2822    MEDIUM
# Name: DEALSIZE, Length: 2823, dtype: object

# %%
df.to_csv('cleaned_data.csv',index=False)

# %%
df1= pd.read_csv('/content/Zudio_sales_data.csv')

# %%
df1.head()
# Out:
#    Store Country          State      City Category Clothing Type  \
# 0  Zudio   India      Karnataka     Jalna    Women       Dresses
# 1  Zudio   India        Gujarat     Patna     Kids        Skirts
# 2  Zudio   India  Uttar Pradesh   Kolkata      Men       Hoodies
# 3  Zudio   India    West Bengal   Kolkata    Women       Dresses
# 4  Zudio   India    West Bengal  Guwahati      Men       Dresses
#
#    Store Number  Postal Code Store Type Store Open Date  ...  \
# 0            30       411084      Owned      2022-06-04  ...
# 1            48       404562      Owned      2020-12-19  ...
# 2            97       437773     Rented      2023-09-04  ...
# 3            93       431725      Owned      2024-04-11  ...
# 4            51       415370      Owned      2022-05-29  ...
#
#    Security Features Order ID  Order Date     Month Customer ID  \
# 0              Alarm    88240  2024-11-06  November      233084
# 1              Alarm    78145  2024-06-17      June      926472
# ...

# %%
df1.tail()
# Out:
#       Store Country          State        City Category Clothing Type  \
# 7894  Zudio   India  Uttar Pradesh  Chandigarh     Kids         Jeans
# 7895  Zudio   India  Uttar Pradesh  Aurangabad     Kids       Jackets
# 7896  Zudio   India     Tamil Nadu        Pune     Kids      T-shirts
# 7897  Zudio   India          Delhi     Madurai      Men         Shoes
# 7898  Zudio   India        Gujarat   Bengaluru    Women        Shirts
#
#       Store Number  Postal Code Store Type Store Open Date  ...  \
# 7894            32       431437      Owned      2024-04-24  ...
# 7895            52       424643      Owned      2024-02-03  ...
# 7896            81       412057      Owned      2021-04-11  ...
# 7897            58       405203     Rented      2022-06-17  ...
# 7898            20       429823      Owned      2023-02-08  ...
#
#       Security Features Order ID  Order Date      Month Customer ID  \
# 7894        CCTV, Alarm    39056  2024-09-27  September      591993
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7899 entries, 0 to 7898
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      7899 non-null   object
#  1   Country                    7899 non-null   object
#  2   State                      7899 non-null   object
#  3   City                       7899 non-null   object
#  4   Category                   7899 non-null   object
#  5   Clothing Type              7899 non-null   object
#  6   Store Number               7899 non-null   int64
#  7   Postal Code                7899 non-null   int64
#  8   Store Type                 7899 non-null   object
#  9   Store Open Date            7899 non-null   object
#  10  Selling Area Size (sq ft)  7899 non-null   int64
#  11  Store Manager              7899 non-null   object
#  12  Manager ID                 7899 non-null   object
# ...

# %%
df1.shape
# Out:
# (7899, 28)

# %%
df1.columns
# Out:
# Index(['Store', 'Country', 'State', 'City', 'Category', 'Clothing Type',
#        'Store Number', 'Postal Code', 'Store Type', 'Store Open Date',
#        'Selling Area Size (sq ft)', 'Store Manager', 'Manager ID',
#        'Store Address', 'Contact Information', 'Operating Hours',
#        'Staff Count', 'Parking Availability', 'Security Features', 'Order ID',
#        'Order Date', 'Month', 'Customer ID', 'Customer Name', 'Product ID',
#        'Price', 'Quantity', 'Sales Profit'],
#       dtype='object')

# %%
df1.describe()
# Out:
#        Store Number    Postal Code  Selling Area Size (sq ft)  Staff Count  \
# count   7899.000000    7899.000000                7899.000000  7899.000000
# mean      50.666034  419982.374984                1112.077478    11.504747
# std       29.095274   11695.237817                 193.239371     5.194722
# min        1.000000  400006.000000                 800.000000     3.000000
# 25%       25.000000  409841.000000                 950.000000     7.000000
# 50%       51.000000  419988.000000                1100.000000    12.000000
# 75%       76.000000  430258.000000                1300.000000    16.000000
# max      100.000000  439985.000000                1400.000000    20.000000
#
#            Order ID    Customer ID   Product ID        Price     Quantity  \
# count   7899.000000    7899.000000  7899.000000  7899.000000  7899.000000
# mean   54920.719965  549440.714521   602.069376  1761.113432     4.519433
# ...

# %%
df1.isnull()
# Out:
#       Store  Country  State   City  Category  Clothing Type  Store Number  \
# 0     False    False  False  False     False          False         False
# 1     False    False  False  False     False          False         False
# 2     False    False  False  False     False          False         False
# 3     False    False  False  False     False          False         False
# 4     False    False  False  False     False          False         False
# ...     ...      ...    ...    ...       ...            ...           ...
# 7894  False    False  False  False     False          False         False
# 7895  False    False  False  False     False          False         False
# 7896  False    False  False  False     False          False         False
# 7897  False    False  False  False     False          False         False
# 7898  False    False  False  False     False          False         False
#
#       Postal Code  Store Type  Store Open Date  ...  Security Features  \
# ...

# %%
df1.isnull().sum()
# Out:
# Store                           0
# Country                         0
# State                           0
# City                            0
# Category                        0
# Clothing Type                   0
# Store Number                    0
# Postal Code                     0
# Store Type                      0
# Store Open Date                 0
# Selling Area Size (sq ft)       0
# Store Manager                   0
# Manager ID                      0
# Store Address                   0
# Contact Information             0
# Operating Hours                 0
# Staff Count                     0
# Parking Availability            0
# Security Features            2038
# Order ID                        0
# Order Date                      0
# Month                           0
# Customer ID                     0
# Customer Name                   0
# Product ID                      0
# Price                           0
# Quantity                        0
# ...

# %%
df1.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7894    False
# 7895    False
# 7896    False
# 7897    False
# 7898    False
# Length: 7899, dtype: bool

# %%
import pandas as pd
df1 = pd.read_csv('/content/Zudio_sales_data.csv')
df1['State']
# Out:
# 0           Karnataka
# 1             Gujarat
# 2       Uttar Pradesh
# 3         West Bengal
# 4         West Bengal
#             ...
# 7894    Uttar Pradesh
# 7895    Uttar Pradesh
# 7896       Tamil Nadu
# 7897            Delhi
# 7898          Gujarat
# Name: State, Length: 7899, dtype: object

# %%
df1[['State','Category']]
# Out:
#               State Category
# 0         Karnataka    Women
# 1           Gujarat     Kids
# 2     Uttar Pradesh      Men
# 3       West Bengal    Women
# 4       West Bengal      Men
# ...             ...      ...
# 7894  Uttar Pradesh     Kids
# 7895  Uttar Pradesh     Kids
# 7896     Tamil Nadu     Kids
# 7897          Delhi      Men
# 7898        Gujarat    Women
#
# [7899 rows x 2 columns]

# %%
df1[['State','Country','Category']]
# Out:
#               State Country Category
# 0         Karnataka   India    Women
# 1           Gujarat   India     Kids
# 2     Uttar Pradesh   India      Men
# 3       West Bengal   India    Women
# 4       West Bengal   India      Men
# ...             ...     ...      ...
# 7894  Uttar Pradesh   India     Kids
# 7895  Uttar Pradesh   India     Kids
# 7896     Tamil Nadu   India     Kids
# 7897          Delhi   India      Men
# 7898        Gujarat   India    Women
#
# [7899 rows x 3 columns]

# %%
df1['City']
# Out:
# 0            Jalna
# 1            Patna
# 2          Kolkata
# 3          Kolkata
# 4         Guwahati
#            ...
# 7894    Chandigarh
# 7895    Aurangabad
# 7896          Pune
# 7897       Madurai
# 7898     Bengaluru
# Name: City, Length: 7899, dtype: object

# %%
df1[20:]
# Out:
#       Store Country          State          City Category Clothing Type  \
# 20    Zudio   India     Tamil Nadu         Thane     Kids       Dresses
# 21    Zudio   India          Delhi         Patna     Kids       Dresses
# 22    Zudio   India        Gujarat  Chhattisgarh     Kids       Dresses
# 23    Zudio   India    West Bengal        Nashik    Women         Shoes
# 24    Zudio   India      Karnataka         Noida     Kids      Sweaters
# ...     ...     ...            ...           ...      ...           ...
# 7894  Zudio   India  Uttar Pradesh    Chandigarh     Kids         Jeans
# 7895  Zudio   India  Uttar Pradesh    Aurangabad     Kids       Jackets
# 7896  Zudio   India     Tamil Nadu          Pune     Kids      T-shirts
# 7897  Zudio   India          Delhi       Madurai      Men         Shoes
# 7898  Zudio   India        Gujarat     Bengaluru    Women        Shirts
#
#       Store Number  Postal Code Store Type Store Open Date  ...  \
# ...

# %%
df1['City'].value_counts()
# Out:
# City
# Kolkata          210
# Mysuru           207
# New Delhi        205
# Jammu            204
# Madurai          204
# Bhopal           203
# Rajkot           202
# Hyderabad        201
# Pune             200
# Indore           200
# Coimbatore       199
# Jalna            199
# Ahmedabad        195
# Bengaluru        194
# Chhattisgarh     193
# Noida            193
# Visakhapatnam    193
# Kochi            193
# Kanpur           190
# Varanasi         190
# Chandigarh       190
# Jaipur           189
# Lucknow          188
# Agra             187
# Surat            187
# Ranchi           185
# Chennai          182
# Solapur          182
# Nashik           182
# Vadodara         181
# Meerut           181
# Nagpur           179
# Patna            178
# Kolhapur         178
# Satara           178
# Goa              176
# Faridabad        172
# Guwahati         171
# Pondicherry      167
# Thane            166
# Aurangabad       166
# Mumbai           159
# ...

# %%
df1['City'].unique()
# Out:
# array(['Jalna', 'Patna', 'Kolkata', 'Guwahati', 'Nashik', 'Lucknow',
#        'Hyderabad', 'Ahmedabad', 'Faridabad', 'Noida', 'Madurai',
#        'Chhattisgarh', 'Bengaluru', 'Agra', 'Thane', 'Chandigarh',
#        'Ranchi', 'Mysuru', 'Vadodara', 'Jammu', 'Varanasi',
#        'Visakhapatnam', 'Bhopal', 'Indore', 'Kolhapur', 'Solapur',
#        'Rajkot', 'Chennai', 'Kanpur', 'Kochi', 'Nagpur', 'Surat',
#        'Pondicherry', 'Goa', 'Mumbai', 'Pune', 'Aurangabad', 'Meerut',
#        'Jaipur', 'New Delhi', 'Satara', 'Coimbatore'], dtype=object)

# %%
df1['City'].nunique()
# Out:
# 42

# %%
df1.loc[0]
# Out:
# Store                                                  Zudio
# Country                                                India
# State                                              Karnataka
# City                                                   Jalna
# Category                                               Women
# Clothing Type                                        Dresses
# Store Number                                              30
# Postal Code                                           411084
# Store Type                                             Owned
# Store Open Date                                   2022-06-04
# Selling Area Size (sq ft)                                950
# Store Manager                                      Lori Hill
# Manager ID                                               M77
# Store Address                PSC 4147, Box 1289 APO AA 19737
# Contact Information                        (014)392-4112x860
# ...

# %%
df1.loc[13,'Order Date']
# Out:
# '2024-05-20'

# %%
df1.loc[12,['State','Country','Category']]
# Out:
# State       Maharashtra
# Country           India
# Category           Kids
# Name: 12, dtype: object

# %%
df1.loc[0:23]
# Out:
#     Store Country          State          City Category Clothing Type  \
# 0   Zudio   India      Karnataka         Jalna    Women       Dresses
# 1   Zudio   India        Gujarat         Patna     Kids        Skirts
# 2   Zudio   India  Uttar Pradesh       Kolkata      Men       Hoodies
# 3   Zudio   India    West Bengal       Kolkata    Women       Dresses
# 4   Zudio   India    West Bengal      Guwahati      Men       Dresses
# 5   Zudio   India    West Bengal        Nashik     Kids       Jackets
# 6   Zudio   India    Maharashtra       Lucknow     Kids       Jackets
# 7   Zudio   India    West Bengal     Hyderabad    Women          Tops
# 8   Zudio   India      Karnataka     Ahmedabad      Men         Shoes
# 9   Zudio   India      Karnataka     Hyderabad     Kids         Jeans
# 10  Zudio   India    Maharashtra       Kolkata      Men       Hoodies
# 11  Zudio   India  Uttar Pradesh        Nashik      Men       Jackets
# ...

# %%
df1.iloc[0:34,3]
# Out:
# 0            Jalna
# 1            Patna
# 2          Kolkata
# 3          Kolkata
# 4         Guwahati
# 5           Nashik
# 6          Lucknow
# 7        Hyderabad
# 8        Ahmedabad
# 9        Hyderabad
# 10         Kolkata
# 11          Nashik
# 12       Faridabad
# 13           Noida
# 14         Madurai
# 15           Noida
# 16    Chhattisgarh
# 17       Bengaluru
# 18         Kolkata
# 19            Agra
# 20           Thane
# 21           Patna
# 22    Chhattisgarh
# 23          Nashik
# 24           Noida
# 25       Bengaluru
# 26      Chandigarh
# 27          Ranchi
# 28            Agra
# 29          Mysuru
# 30           Jalna
# 31        Vadodara
# 32           Jammu
# 33        Varanasi
# Name: City, dtype: object

# %%
df1.iloc[10:23,5]
# Out:
# 10     Hoodies
# 11     Jackets
# 12       Pants
# 13      Skirts
# 14    Sweaters
# 15     Dresses
# 16       Pants
# 17     Hoodies
# 18    T-shirts
# 19    T-shirts
# 20     Dresses
# 21     Dresses
# 22     Dresses
# Name: Clothing Type, dtype: object

# %%
df1.iloc[0:30,[0,3,2]]
# Out:
#     Store          City          State
# 0   Zudio         Jalna      Karnataka
# 1   Zudio         Patna        Gujarat
# 2   Zudio       Kolkata  Uttar Pradesh
# 3   Zudio       Kolkata    West Bengal
# 4   Zudio      Guwahati    West Bengal
# 5   Zudio        Nashik    West Bengal
# 6   Zudio       Lucknow    Maharashtra
# 7   Zudio     Hyderabad    West Bengal
# 8   Zudio     Ahmedabad      Karnataka
# 9   Zudio     Hyderabad      Karnataka
# 10  Zudio       Kolkata    Maharashtra
# 11  Zudio        Nashik  Uttar Pradesh
# 12  Zudio     Faridabad    Maharashtra
# 13  Zudio         Noida        Gujarat
# 14  Zudio       Madurai     Tamil Nadu
# 15  Zudio         Noida      Rajasthan
# 16  Zudio  Chhattisgarh    Maharashtra
# 17  Zudio     Bengaluru      Rajasthan
# 18  Zudio       Kolkata      Rajasthan
# 19  Zudio          Agra      Rajasthan
# 20  Zudio         Thane     Tamil Nadu
# 21  Zudio         Patna          Delhi
# 22  Zudio  Chhattisgarh        Gujarat
# ...

# %%
df1.iloc[0:23,[14,17,20]]
# Out:
#        Contact Information Parking Availability  Order Date
# 0        (014)392-4112x860        Not Available  2024-11-06
# 1          +1-838-710-2029        Not Available  2024-06-17
# 2       523.732.1176x07696        Not Available  2024-08-17
# 3    +1-846-657-3934x68953        Not Available  2024-03-27
# 4            (336)147-6341        Not Available  2024-04-08
# 5          +1-149-000-5823            Available  2024-04-25
# 6     +1-886-886-9185x9650            Available  2024-06-19
# 7            (646)899-9850            Available  2024-06-11
# 8        (337)998-4800x283            Available  2024-01-24
# 9      (315)462-2864x05458            Available  2024-02-02
# 10    001-666-518-4316x287            Available  2024-07-16
# 11            535-871-6788            Available  2024-07-22
# 12  001-190-519-8370x89059        Not Available  2024-05-17
# 13    +1-579-715-4264x6243            Available  2024-05-20
# 14   +1-681-005-5756x68861        Not Available  2024-10-26
# ...

# %%
df1.drop_duplicates(inplace=True)

# %%
df1.rename(columns={'Store Number':'Store No'},inplace=True)

# %%
df1['Store Number']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Store Number'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_5530/3071175204.py in <cell line: 0>()
# ----> 1 df1['Store Number']
#
# ...

# %%
df1['Order Date']
# Out:
# 0       2024-11-06
# 1       2024-06-17
# 2       2024-08-17
# 3       2024-03-27
# 4       2024-04-08
#            ...
# 7894    2024-09-27
# 7895    2024-03-16
# 7896    2024-12-02
# 7897    2024-07-29
# 7898    2024-04-08
# Name: Order Date, Length: 7899, dtype: object

# %%
df1['Order Date']=pd.to_datetime(df1['Order Date'])

# %%
df1['Order Date']
# Out:
# 0      2024-11-06
# 1      2024-06-17
# 2      2024-08-17
# 3      2024-03-27
# 4      2024-04-08
#           ...
# 7894   2024-09-27
# 7895   2024-03-16
# 7896   2024-12-02
# 7897   2024-07-29
# 7898   2024-04-08
# Name: Order Date, Length: 7899, dtype: datetime64[ns]

# %%
df1['year']=df1['Order Date'].dt.year

# %%
df1['year']
# Out:
# 0       2024
# 1       2024
# 2       2024
# 3       2024
# 4       2024
#         ...
# 7894    2024
# 7895    2024
# 7896    2024
# 7897    2024
# 7898    2024
# Name: year, Length: 7899, dtype: int32

# %%
df1['month']=df1['Order Date'].dt.month

# %%
df1['month']
# Out:
# 0       11
# 1        6
# 2        8
# 3        3
# 4        4
#         ..
# 7894     9
# 7895     3
# 7896    12
# 7897     7
# 7898     4
# Name: month, Length: 7899, dtype: int32

# %%
df1['day']=df1['Order Date'].dt.day

# %%
df1['day']
# Out:
# 0        6
# 1       17
# 2       17
# 3       27
# 4        8
#         ..
# 7894    27
# 7895    16
# 7896     2
# 7897    29
# 7898     8
# Name: day, Length: 7899, dtype: int32

# %%
df1['PROFIT_EST']=df1['Sales Profit']*0.2

# %%
df1['PROFIT_EST']
# Out:
# 0        783.20
# 1        166.24
# 2        231.20
# 3       1185.12
# 4        530.40
#          ...
# 7894     227.04
# 7895     290.24
# 7896     156.88
# 7897     650.88
# 7898    1109.20
# Name: PROFIT_EST, Length: 7899, dtype: float64

# %%
df1.drop('PROFIT_EST',axis=1,inplace=True)

# %%
df1['Manager']=df1['Store Manager']+' '+ df1['Manager ID']

# %%
df1['Manager']
# Out:
# 0               Lori Hill M77
# 1         Deborah Jackson M89
# 2           Adam Anderson M71
# 3           Anthony Smith M40
# 4          Matthew Romero M24
#                 ...
# 7894         Stacy Morgan M68
# 7895        Gregory Davis M16
# 7896           Paul Perez M21
# 7897            Eric Kirk M87
# 7898    Crystal Maldonado M80
# Name: Manager, Length: 7899, dtype: object

# %%
state_sales=df1.groupby('State')['Sales Profit'].sum()

# %%
state_sales
state_sales.plot(kind='bar')
# Out:
# <Axes: xlabel='State'>

# %%
df1.groupby('State')['Sales Profit'].sum()
# Out:
# State
# Delhi            3191315.6
# Gujarat          3050520.8
# Karnataka        3034747.6
# Maharashtra      3089685.6
# Rajasthan        3187911.6
# Tamil Nadu       3085623.2
# Uttar Pradesh    3163014.0
# West Bengal      3242314.8
# Name: Sales Profit, dtype: float64

# %%
df1['Category']
# Out:
# 0       Women
# 1        Kids
# 2         Men
# 3       Women
# 4         Men
#         ...
# 7894     Kids
# 7895     Kids
# 7896     Kids
# 7897      Men
# 7898    Women
# Name: Category, Length: 7899, dtype: object

# %%
df1['Category']=df1['Category'].str.upper()

# %%
df1['Category']
# Out:
# 0       WOMEN
# 1        KIDS
# 2         MEN
# 3       WOMEN
# 4         MEN
#         ...
# 7894     KIDS
# 7895     KIDS
# 7896     KIDS
# 7897      MEN
# 7898    WOMEN
# Name: Category, Length: 7899, dtype: object

# %%
df1.to_csv('clean_data.csv',index=False)
