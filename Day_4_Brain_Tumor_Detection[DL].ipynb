# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahma-up/ADD-ON/blob/main/Day_4_Brain_Tumor_Detection%5BDL%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image

# %%
zip_path = "/content/archive (21).zip"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("dataset")

print("Dataset Extracted Successfully")
# Out:
# Dataset Extracted Successfully

# %%
train_data = ImageDataGenerator(rescale=1./255)

train_generator = train_data.flow_from_directory(
    "dataset",
    target_size=(128,128),
    batch_size=32,
    class_mode="binary"
)
# Out:
# Found 506 images belonging to 3 classes.

# %%
train_generator = train_data.flow_from_directory(
    "dataset/brain_tumor_dataset",
    target_size=(128,128),
    batch_size=32,
    class_mode="binary"
)
# Out:
# Found 253 images belonging to 2 classes.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32,(3,3),activation='relu',input_shape=(128,128,3)),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(1,activation='sigmoid')
])

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(train_generator, epochs=5)
# Out:
# Epoch 1/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 894ms/step - accuracy: 0.5494 - loss: 1.6627
# Epoch 2/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 708ms/step - accuracy: 0.6996 - loss: 0.5933
# Epoch 3/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 841ms/step - accuracy: 0.7984 - loss: 0.4804
# Epoch 4/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 748ms/step - accuracy: 0.8458 - loss: 0.3716
# Epoch 5/5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 787ms/step - accuracy: 0.8893 - loss: 0.2895

# %%
from google.colab import files

# %%
img = image.load_img("/content/BRAIN.jpg", target_size=(128,128))
img = image.img_to_array(img)/255.0
img = np.expand_dims(img, axis=0)

prediction = model.predict(img)

if prediction[0][0] > 0.5:
    print("🧠 Tumor Detected")
else:
    print("✅ No Tumor Detected")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 🧠 Tumor Detected

# %%
img = image.load_img("/content/images (1).jpg", target_size=(128,128))
img = image.img_to_array(img)/255.0
img = np.expand_dims(img, axis=0)

prediction = model.predict(img)

if prediction[0][0] > 0.5:
    print("🧠 Tumor Detected")
else:
    print("✅ No Tumor Detected")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ✅ No Tumor Detected

# %%
img = image.load_img("/content/download3.jpg", target_size=(128,128))
img = image.img_to_array(img)/255.0
img = np.expand_dims(img, axis=0)

prediction = model.predict(img)

if prediction[0][0] > 0.5:
    print("🧠 Tumor Detected")
else:
    print("✅ No Tumor Detected")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ No Tumor Detected

# %%
img = image.load_img("/content/images (2).jpg", target_size=(128,128))
img = image.img_to_array(img)/255.0
img = np.expand_dims(img, axis=0)

prediction = model.predict(img)

if prediction[0][0] > 0.5:
    print("🧠 Tumor Detected")
else:
    print("✅ No Tumor Detected")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ✅ No Tumor Detected
